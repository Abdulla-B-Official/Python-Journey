# %% [markdown]
# # Number Guessing Game

# %% [markdown]
# ## Level 1.Print if the user guessed number is right or not.

# %%
secret_number = 56
user_input = int(input("Enter your guess :"))
if secret_number == user_input:
   print("Congradulations! You're guess is right!")
else:
   print("Sorry,your guess is wrong")
# Out:
# Enter your guess : 45
# Sorry,your guess is wrong

# %% [markdown]
# Notes : Type casting : is the process of coverting a particular data type into an another data type is called type casting

# %% [markdown]
# ## Level 2.Print if the user guessed number is right or not but with max of 7 trails

# %% [markdown]
# #### 2.1 Using For Loop - end interation number is defined

# %%
secret_number = 56
for i in range(0,7):
   user_input = int(input("Enter your guess :"))
   if secret_number == user_input:
      print("Congradulations! You're guess is right!")
      break;
   else:
      print("Sorry,your guess is wrong")
# Out:
# Enter your guess : 45
# Sorry,your guess is wrong
# Enter your guess : 34
# Sorry,your guess is wrong
# Enter your guess : 34
# Sorry,your guess is wrong
# Enter your guess : 23
# Sorry,your guess is wrong
# Enter your guess : 23
# Sorry,your guess is wrong
# Enter your guess : 67
# Sorry,your guess is wrong
# Enter your guess : 76
# Sorry,your guess is wrong

# %% [markdown]
# #### 2.2 While Loop - When end number is not defined and the instruction has to executed infinite times

# %%
secret_number = 56
while True:
   user_input = int(input("Enter your guess :"))
   if secret_number == user_input:
      print("Congradulations! You're guess is right!")
      break;
   else:
      print("Sorry,your guess is wrong")
# Out:
# Enter your guess : 56
# Congradulations! You're guess is right!

# %% [markdown]
# ## Level 3: Give multiple conditions
#
# 1. User should enter the number between 1-100 . if it's entered wrong ,the program should say , "Invalid Number"
# 2. if the user guessed number > secret number,then program should say,"Your number is greater than the secret number"
# 3. if the user guessed number < secret number,then program should say,"Your number is lesser than the secret number"

# %%
print("Welcome to Number Guessing Game!!! ")
print("Guess the Number between 1 to 100")
secret_number =98
for i in range(1,8):
 user_input=int(input("Enter the Number"))
 if user_input<1 or user_input>100:
     print("Invalid Number! Please enter the number between 1 to 100")
 elif user_input > secret_number:
     print("Your Num is Higher!")
 elif user_input < secret_number:
     print("Your Num is Lesser!")
 else:
     print("Your Number is Correct !")
     print(f"Congradulations! You have guessed the number {secret_number} in {i} attempts")
     break
# Out:
# Welcome to Number Guessing Game!!!
# Guess the Number between 1 to 100
# Enter the Number 0
# Invalid Number! Please enter the number between 1 to 100
# Enter the Number 101
# Invalid Number! Please enter the number between 1 to 100
# Enter the Number 88
# Your Num is Lesser!
# Enter the Number 99
# Your Num is Higher!
# Enter the Number 97
# Your Num is Lesser!
# Enter the Number 92
# Your Num is Lesser!
# Enter the Number 90
# Your Num is Lesser!

# %% [markdown]
# in this we have used the print formatting to display the attemps and the number

# %% [markdown]
# ## Level 4: Setting Multiple Conditions

# %%
print("Welcome to Number Guessing Game!!! ")
print("Guess the Number between 1 to 100")
secret_number =98
for i in range(1,8):
 user_input=int(input("Enter the Number"))
 if user_input<1 or user_input>100:
     print("Invalid Number! Please enter the number between 1 to 100")
 elif user_input > secret_number:
     print("Your Num is Higher!")
 elif user_input < secret_number:
     print("Your Num is Lesser!")
 else:
     print("Your Number is Correct !")
     break
if secret_number==user_input:     
   print(f"Congradulations! You have guessed the number {secret_number} in {i} attempts")
else:
    print("Sorry! All your trials is exceeded. Try Again !!")
# Out:
# Welcome to Number Guessing Game!!!
# Guess the Number between 1 to 100
# Enter the Number 29
# Your Num is Lesser!
# Enter the Number 50
# Your Num is Lesser!
# Enter the Number 99
# Your Num is Higher!
# Enter the Number 70
# Your Num is Lesser!
# Enter the Number 89
# Your Num is Lesser!
# Enter the Number 85
# Your Num is Lesser!
# Enter the Number 95
# Your Num is Lesser!
# Sorry! All your trials is exceeded. Try Again !!

# %% [markdown]
# ## Level 5 : The secret number should be random

# %%
import random
print("Welcome to Number Guessing Game!!! ")
print("Guess the Number between 1 to 100")

secret_number = random.randint(1,100)

for i in range(1,8):
    user_input=int(input("Enter the Number"))
    if user_input<1 or user_input>100:
       print("Invalid Number! Please enter the number between 1 to 100")
    elif user_input > secret_number:
       print("Your Num is Higher!")
    elif user_input < secret_number:
       print("Your Num is Lesser!")
    else:
       print("Your Number is Correct !")
       break
if secret_number == user_input:     
   print(f"Congradulations! You have guessed the number {secret_number} in {i} attempts")
else:
    print("Sorry! All your trials is exceeded. Try Again !!")
# Out:
# Welcome to Number Guessing Game!!!
# Guess the Number between 1 to 100
# Enter the Number 78
# Your Num is Lesser!
# Enter the Number 99
# Your Num is Higher!
# Enter the Number 90
# Your Num is Higher!
# Enter the Number 80
# Your Num is Lesser!
# Enter the Number 85
# Your Num is Lesser!
# Enter the Number 88
# Your Num is Higher!
# Enter the Number 87
# Your Number is Correct !
# Congradulations! You have guessed the number 87 in 7 attempts

# %% [markdown]
# ## 5.2 Take out the trails limit for try

# %%
import random
print("Welcome to Number Guessing Game!!! ")
print("Guess the Number between 1 to 100")

secret_number = random.randint(1,100)
while True:
    user_input=int(input("Enter the Number"))
    if user_input<1 or user_input>100:
       print("Invalid Number! Please enter the number between 1 to 100")
    elif user_input > secret_number:
       print("Your Num is Higher!")
    elif user_input < secret_number:
       print("Your Num is Lesser!")
    else:
       print("Your Number is Correct !")
       break
if secret_number == user_input:     
   print(f"Congradulations! You have guessed the number {secret_number} in {i} attempts")
else:
    print("Sorry! All your trials is exceeded. Try Again !!")
# Out:
# Welcome to Number Guessing Game!!!
# Guess the Number between 1 to 100
# Enter the Number 90
# Your Num is Lesser!
# Enter the Number 95
# Your Num is Lesser!
# Enter the Number 99
# Your Number is Correct !
# Congradulations! You have guessed the number 99 in 7 attempts

# %% [markdown]
# ## Level 6 - How to handle Invaild Characters or Values

# %%
import random
print("Welcome to Number Guessing Game!!! ")
print("Guess the Number between 1 to 100")

secret_number = random.randint(1,100)

for i in range(1,8):
    try:
        user_input=int(input("Enter the Number"))
        if user_input<1 or user_input>100:
           print("Invalid Number! Please enter the number between 1 to 100")
        elif user_input > secret_number:
           print("Your Num is Higher!")
        elif user_input < secret_number:
           print("Your Num is Lesser!")
        else:
           print("Your Number is Correct !")
           break
    except ValueError:
        print("Invalid Characters Please enter the number between 1 to 100")
if secret_number == user_input:     
   print(f"Congradulations! You have guessed the number {secret_number} in {i} attempts")
else:
    print("Sorry! All your trials is exceeded. Try Again !!")
# Out:
# Welcome to Number Guessing Game!!!
# Guess the Number between 1 to 100
# Enter the Number a
# Invalid Characters Please enter the number between 1 to 100
# Enter the Number 98
# Your Num is Higher!
# Enter the Number 50
# Your Num is Higher!
# Enter the Number 10
# Your Num is Lesser!
# Enter the Number 25
# Your Num is Lesser!
# Enter the Number 38
# Your Num is Higher!
# Enter the Number 35
# Your Number is Correct !
# Congradulations! You have guessed the number 35 in 7 attempts

# %% [markdown]
# ## Level 7 - Take this program to run as a function when it is called
#
# step 1 - define a function
#
# step 2 - call the function

# %%
def number_guessing_game():
    
    import random
    print("Welcome to Number Guessing Game!!! ")
    print("Guess the Number between 1 to 100")
    
    secret_number = random.randint(1,100)
    
    for i in range(1,8):
        try:
            user_input=int(input("Enter the Number"))
            if user_input<1 or user_input>100:
               print("Invalid Number! Please enter the number between 1 to 100")
            elif user_input > secret_number:
               print("Your Num is Higher!")
            elif user_input < secret_number:
               print("Your Num is Lesser!")
            else:
               print("Your Number is Correct !")
               break
        except ValueError:
            print("Invalid Characters Please enter the number between 1 to 100")
    if secret_number == user_input:     
       print(f"Congradulations! You have guessed the number {secret_number} in {i} attempts")
    else:
        print("Sorry! All your trials is exceeded. Try Again !!")

# %%
number_guessing_game()
# Out:
# Welcome to Number Guessing Game!!!
# Guess the Number between 1 to 100
# Enter the Number 56
# Your Num is Lesser!
# Enter the Number 70
# Your Num is Lesser!
# Enter the Number 99
# Your Num is Higher!
# Enter the Number 90
# Your Number is Correct !
# Congradulations! You have guessed the number 90 in 4 attempts
