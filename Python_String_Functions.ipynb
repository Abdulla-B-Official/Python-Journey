# %% [markdown]
# # Task 1 - String Functions

# %%
learner_1="krish  "
learner_2="   priya"
learner_3="athul   "
learner_4="   jaga   "
learner_5="RaMa_KrisHnA" 
learner_6="Hii I am Fariq."
learner_7="R\ta\tk\te\ts\th"
learner_8="fariq age is {age:.0f} !"
learner_9="learner {name} his age is {age} !"
learner_10="Wasim and his age is 32"
learner_11="Wasim32"
learner_12="Sanu"
learner_13="13"
learner_14="13.00"
learner_15="   "
learner_16="Sanu said'Hiii,I am Sanu'"
myvar={"name":"Fariq","age":23}
teachers=("Sam","John","Peter")
learners="sam, john, kavin"
welcome="welcome to the course"

# %%
car_1="audi   "
car_2="   benz"
car_3="   bmw   "
car_4="LaNd RoVer"
car_5="T\tO\tY\tO\tT\tA"
car_6="Xuv700"
car_7="Nissan"
car_8="DODGE"
milege_1="20"
milege_2="18.75"
milege_3="   "
showroom_1="welcome to nexa showroom"
showroom_2="Our {name} gives {hp} Horsepower"
showroom_3="Suzuki gives mileage more the 20"
showroom_4="Mercedes Manager said'Mercedes Welcomes you' "
showroom_5={"name":"BMW","model":320}
showroom_6="BMW gives mileage more the {milege:.2f}"
showroom_7="Mercedes Manager said \n'Mercedes Welcomes you' "
fastest=("BMW","BENZ","AUDI","VW")
offroad="Lc | Raptor | Cardilac"

# %%
print(learner_1,learner_2,learner_3,learner_4)
# Out:
# krish      priya athul       jaga

# %%
print(learner_1)
print(learner_2)
print(learner_3)
print(learner_4)
# Out:
# krish
#    priya
# athul
#    jaga

# %% [markdown]
# ## 1.1 ISUPPER() - Returns True if all characters in the string are upper case

# %% [markdown]
# ### Example 1

# %%
learner_1="krish  "
learner_1.isupper()
# Out:
# False

# %% [markdown]
# ### Example 2

# %%
car_8="DODGE"
car_8.isupper()
# Out:
# True

# %% [markdown]
# ## 1.2 COUNT() - Returns the number of times a specified value occurs in a string

# %% [markdown]
# ### Example 1

# %%
learner_16="Sanu said'Hiii,I am Sanu'"
learner_16.count("Sanu")
# Out:
# 2

# %% [markdown]
# ### Example 2

# %%
showroom_4="Mercedes Manager said'Mercedes Welcomes you' "
showroom_4.count("Mercedes")
# Out:
# 2

# %% [markdown]
# ## 1.3 UPPER() - Converts a string into upper case

# %% [markdown]
# ### Example 1

# %%
learner_1="krish  "
learner_1.upper()
# Out:
# 'KRISH  '

# %% [markdown]
# ### Example 2

# %%
car_1="audi   "
car_1.upper()
# Out:
# 'AUDI   '

# %% [markdown]
# ## 1.4 LSTRIP() - Returns a left trim version of the string

# %% [markdown]
# ### Example 1

# %%
learner_2="   priya"
learner_2.lstrip()
# Out:
# 'priya'

# %% [markdown]
# ### Example 2

# %%
car_2="   benz"
car_2.lstrip()
# Out:
# 'benz'

# %% [markdown]
# ## 1.5 RSTRIP() - Return a right trim version of the string

# %% [markdown]
# ### Example 1

# %%
learner_3="athul   "
learner_3.rstrip()
# Out:
# 'athul'

# %% [markdown]
# ### Example 2

# %%
car_1="audi   "
car_1.rstrip()
# Out:
# 'audi'

# %% [markdown]
# ## 1.6 STRIP() - Returns a trimmed version of the string

# %% [markdown]
# ### Example 1

# %%
learner_4="   jaga   "
learner_4.strip()
# Out:
# 'jaga'

# %% [markdown]
# ### Example 2

# %%
car_3="   bmw   "
car_3.strip()
# Out:
# 'bmw'

# %% [markdown]
# ## 1.7 ZFILL() - Fills the string with a specified number of 0 values at the beginning

# %% [markdown]
# ### Example 1

# %%
learner_1="krish  "
learner_1.zfill(11)
# Out:
# '0000krish  '

# %% [markdown]
# ### Example 2

# %%
car_1="audi   "
car_1.zfill(15)
# Out:
# '00000000audi   '

# %% [markdown]
# ## 1.8 CASEFOLD() - Converts string into lower case

# %% [markdown]
# ### Example 1

# %%
learner_5="RaMa_KrisHnA" 
learner_5.casefold()
# Out:
# 'rama_krishna'

# %% [markdown]
# ### Example 2

# %%
car_4="LaNd RoVer"
car_4.casefold()
# Out:
# 'land rover'

# %% [markdown]
# ## 1.9 CENTER() - Returns a centered string

# %% [markdown]
# ### Example 1

# %%
learner_5="RaMa_KrisHnA" 
learner_5.center(25)
# Out:
# '       RaMa_KrisHnA      '

# %% [markdown]
# ### Example 2

# %%
car_4="LaNd RoVer"
car_4.center(40)
# Out:
# '               LaNd RoVer               '

# %% [markdown]
# ## 1.10 ENDSWITH() - Returns true if the string ends with the specified value

# %% [markdown]
# ### Example 1

# %%
learner_6="Hii I am Fariq."
learner_6.endswith(".")
# Out:
# True

# %% [markdown]
# ### Example 2

# %%
showroom_1="Welcome to Nexa Showroom"
showroom_1.endswith(".")
# Out:
# False

# %% [markdown]
# ## 1.11 STARTWITH() - Returns true if the string starts with the specified value

# %% [markdown]
# ### Example 1

# %%
learner_6="Hii I am Fariq."
learner_6.startswith(".")
# Out:
# False

# %% [markdown]
# ### Example 2

# %%
showroom_1="Welcome to Nexa Showroom"
showroom_1.startswith("W")
# Out:
# True

# %% [markdown]
# ## 1.12 EXPANDTABS - Sets the tab size of the string

# %% [markdown]
# ### Example 1

# %%
learner_7="R\ta\tk\te\ts\th"
learner_7.expandtabs(7)
# Out:
# 'R      a      k      e      s      h'

# %% [markdown]
# ### Example 2

# %%
car_5="T\tO\tY\tO\tT\tA"
car_5.expandtabs(5)
# Out:
# 'T    O    Y    O    T    A'

# %% [markdown]
# ## 1.13 FIND() - Searches the string for specified value and returns the position of where it was found

# %% [markdown]
# ### Example 1

# %%
learner_6="Hii I am Fariq."
learner_6.find("I")
# Out:
# 4

# %% [markdown]
# ### Example 2

# %%
showroom_1="Welcome to Nexa Showroom"
showroom_1.find("Nexa")
# Out:
# 11

# %% [markdown]
# ## 1.14 FORMAT() - Format specified values in a string

# %% [markdown]
# ### Example 1

# %%
learner_8="fariq age is {age:.0f} !"
learner_8.format(age = 23)
# Out:
# 'fariq age is 23 !'

# %% [markdown]
# ### Example 2

# %%
showroom_6="BMW gives mileage more the {mileage:.2f} !"
showroom_6.format(mileage =17.25)
# Out:
# 'BMW gives mileage more the 17.25 !'

# %% [markdown]
# ## 1.15 FORMAT_MAP() - Formats specified values in a string

# %% [markdown]
# ### Example 1

# %%
myvar={"name":"Fariq","age":23}
learner_9="learner {name} his age is {age} !"
learner_9.format_map(myvar)
# Out:
# 'learner Fariq his age is 23 !'

# %% [markdown]
# ### Example 2

# %%
showroom_5={"name":"BMW","model":320}
s_cars="The {name} {model}d is a sedan !"
s_cars.format_map(showroom_5)
# Out:
# 'The BMW 320d is a sedan !'

# %% [markdown]
# ## 1.16 INDEX() - Searches the string for a specified value and returns the position of where it was found

# %% [markdown]
# ### Example 1

# %%
learner_10="Wasim and his age is 32"
learner_10.index("his")
# Out:
# 10

# %% [markdown]
# ### Example 2

# %%
showroom_3="Suzuki gives mileage more the 20"
showroom_3.index("mileage")
# Out:
# 13

# %% [markdown]
# ## 1.17 ISALNUM() - Returns True if all characters in the string are in the alphanumeric

# %% [markdown]
# ### Example 1

# %%
learner_10="Wasim and his age is 32"
learner_10.isalnum()
# Out:
# False

# %% [markdown]
# ### Example 2

# %%
car_8="DODGE"
car_8.isalnum()
# Out:
# True

# %% [markdown]
# ## 1.18 ISALPHA() - Returns True if all characters in the string are in the alphabet

# %% [markdown]
# ### Example 1

# %%
learner_11="Wasim32"
learner_11.isalpha()
# Out:
# False

# %% [markdown]
# ### Example 2

# %%
car_7="Nissan"
car_7.isalpha()
# Out:
# True

# %% [markdown]
# ## 1.19 ISASCII() - Returns True if all characters in the string are ascii characters

# %% [markdown]
# ### Example 1

# %%
learner_11="Wasim32"
learner_11.isascii()
# Out:
# True

# %% [markdown]
# ### Example 2

# %%
car_6="Xuv$700"
car_6.isascii()
# Out:
# True

# %% [markdown]
# ## 1.20 ISDECIMAL() - Returns True if all characters in the string are decimals

# %% [markdown]
# ### Example 1

# %%
learner_13="13"
learner_13.isdecimal()
# Out:
# True

# %% [markdown]
# ### Example 2

# %%
milege_2="18.75"
milege_2.isdecimal()
# Out:
# False

# %% [markdown]
# ## 1.21 ISDIGIT() - Returns True if all characters in the string are digits

# %% [markdown]
# ### Example 1

# %%
learner_13="13"
learner_13.isdigit()
# Out:
# True

# %% [markdown]
# ### Example 2

# %%
milege_2="18.75"
milege_2.isdecimal()
# Out:
# False

# %% [markdown]
# ## 1.22 ISIDENTIFIER() - Returns True if the string is an identifier

# %% [markdown]
# ### Example 1

# %%
learner_12="Sanu"
learner_12.isidentifier()
# Out:
# True

# %% [markdown]
# ### Example 2

# %%
milege_1="20"
milege_1.isidentifier()
# Out:
# False

# %% [markdown]
# ## 1.23 ISNUMERIC() - Returns True if all characters in the string are numeric

# %% [markdown]
# ### Example 1

# %%
learner_13="13"
learner_13.isnumeric()
# Out:
# True

# %% [markdown]
# ### Example 2

# %%
car_7="Nissan"
car_7.isnumeric()
# Out:
# False

# %% [markdown]
# ## 1.24 ISSPACE() - Returns True if all characters in the string are whitespaces

# %% [markdown]
# ### Example 1

# %%
learner_15="   "
learner_15.isspace()
# Out:
# True

# %% [markdown]
# ### Example 2

# %%
car_7="Nissan"
car_7.isspace()
# Out:
# False

# %% [markdown]
# ## 1.25 TITLE() - Converts the first character of each word to upper case

# %% [markdown]
# ### Example 1

# %%
welcome="welcome to the course"
welcome.title()
# Out:
# 'Welcome To The Course'

# %% [markdown]
# ### Example 2

# %%
showroom_1="welcome to nexa showroom"
showroom_1.title()
# Out:
# 'Welcome To Nexa Showroom'

# %% [markdown]
# ## 1.26 ISTITLE() - Returns True if the string follows the rules of a title

# %% [markdown]
# ### Example 1

# %%
learner_12="Sanu"
learner_12.istitle()
# Out:
# True

# %% [markdown]
# ### Example 2

# %%
car_8="DODGE"
car_8.istitle()
# Out:
# False

# %% [markdown]
# ## 1.27 JOIN() - Joins the elements of an iterable to the end of the string

# %% [markdown]
# ### Example 1

# %%
teachers=("Sam","John","Peter")
joining=" | ".join(teachers)
joining
# Out:
# 'Sam | John | Peter'

# %% [markdown]
# ### Example 2

# %%
fastest=("BMW","BENZ","AUDI","VW")
"|".join(fastest)
# Out:
# 'BMW|BENZ|AUDI|VW'

# %% [markdown]
# ## 1.28 LJUST() - Returns a left justified version of the string

# %% [markdown]
# ### Example 1

# %%
learner_12="Sanu"
space_adjust=learner_12.ljust(10)   
space_adjust
# Out:
# 'Sanu      '

# %% [markdown]
# ### Example 2

# %%
car_7="Nissan"
car_7.ljust(15)
# Out:
# 'Nissan         '

# %% [markdown]
# ## 1.29 RJUST() - Returns a right justified version of the string

# %% [markdown]
# ### Example 1

# %%
learner_12="Sanu"
space_adjust=learner_12.rjust(10) 
space_adjust
# Out:
# '      Sanu'

# %% [markdown]
# ### Example 2

# %%
car_7="Nissan"
car_7.rjust(15)
# Out:
# '         Nissan'

# %% [markdown]
# ## 1.30 TRANSLATE() - Returns a translated string
# #### Uses a dictionary with ascii codes to replace 83 (S) with 80 (P)

# %% [markdown]
# ### Example 1

# %%
mydict={83:80}
txt="Hello Sam !"
print(txt.translate(mydict))
# Out:
# Hello Pam !

# %% [markdown]
# ## 1.31 MAKETRANS() - Returns a translation table to be used in translations

# %% [markdown]
# ### Example 1

# %%
learner_12="Sanu"
translating=str.maketrans("Sanu","Manu") 
print(learner_12.translate(translating))
# Out:
# Manu

# %% [markdown]
# ### Example 2

# %%
car_7="Nissan"
trans=str.maketrans("Nissan","Kissan")
print(car_7.translate(trans))
# Out:
# Kissan

# %% [markdown]
# ## 1.32 PARTITION() - Returns a tuple where the string is parted into three parts

# %% [markdown]
# ### Example 1

# %%
learner_10="Wasim and his age is 32"
partitioning=learner_10.partition("age") 
partitioning
# Out:
# ('Wasim and his ', 'age', ' is 32')

# %% [markdown]
# ### Example 2

# %%
showroom_3="Suzuki gives mileage more the 20"
partitiong=showroom_3.partition("mileage") 
partitiong
# Out:
# ('Suzuki gives ', 'mileage', ' more the 20')

# %% [markdown]
# ## 1.33 RPARTITION() - Returns a tuple where the string is parted into three parts

# %% [markdown]
# ### Example 1

# %%
learner_10="Wasim and his age is 32"
rpartitioning=learner_10.rpartition("age")        
rpartitioning
# Out:
# ('Wasim and his ', 'age', ' is 32')

# %% [markdown]
# ### Example 2

# %%
showroom_3="Suzuki gives mileage more the 20"
rpartitiong=showroom_3.partition("mileage") 
rpartitiong
# Out:
# ('Suzuki gives ', 'mileage', ' more the 20')

# %% [markdown]
# ## 1.34 REPLACE() - Returns a string where a specified value is replaced with a specified value

# %% [markdown]
# ### Example 1

# %%
learner_10="Wasim and his age is 32"
replacing =learner_10.replace("Wasim","Ashick") 
replacing
# Out:
# 'Ashick and his age is 32'

# %% [markdown]
# ### Example 2

# %%
showroom_3="Suzuki gives mileage more the 20"
showroom_3.replace("Suzuki","Maruthi")
# Out:
# 'Maruthi gives mileage more the 20'

# %% [markdown]
# ## 1.35 RFIND() - Searches the string for a specified value and returns the last position of where it was found

# %% [markdown]
# ### Example 1

# %%
learner_16="Sanu said'Hiii,I am Sanu'"
r_find=learner_16.rfind("Sanu")         
r_find
# Out:
# 20

# %% [markdown]
# ### Example 2

# %%
showroom_4="Mercedes Manager said'Mercedes Welcomes you' "
showroom_4.rfind("Mercedes")
# Out:
# 22

# %% [markdown]
# ## 1.36 RINDEX() - Searches the string for a specified value and returns the last position of where it was found

# %% [markdown]
# ### Example 1

# %%
learner_16="Sanu said'Hiii,I am Sanu'"
rangefind=learner_16.rindex("Sanu")        
rangefind
# Out:
# 20

# %% [markdown]
# ### Example 2

# %%
showroom_4="Mercedes Manager said'Mercedes Welcomes you' "
showroom_4.rindex("Mercedes")
# Out:
# 22

# %% [markdown]
# ## 1.37 SPLIT() - Splits the string at the specified separator, and returns a list

# %% [markdown]
# ### Example 1

# %%
welcome="welcome to the course"
split=welcome.split()          
split
# Out:
# ['welcome', 'to', 'the', 'course']

# %% [markdown]
# ### Example 2

# %%
showroom_1="welcome to nexa showroom"
showroom_1.split()
# Out:
# ['welcome', 'to', 'nexa', 'showroom']

# %% [markdown]
# ## 1.38 RSPLIT() - Splits the string at the specified separator, and returns a list

# %% [markdown]
# ### Example 1

# %%
learners="sam, john, kavin"
rightsplit=learners.rsplit(", ")            
rightsplit
# Out:
# ['sam', 'john', 'kavin']

# %% [markdown]
# ### Example 2

# %%
offroad="Lc | Raptor | Cardilac"
offroad.rsplit(" | ")
# Out:
# ['Lc', 'Raptor', 'Cardilac']

# %% [markdown]
# ## 1.39 SPLITLINES() - Splits the string at line breaks and returns a list

# %% [markdown]
# ### Example 1

# %%
learner_16="Sanu said \n 'Hiii I am Sanu'"
linesplit=learner_16.splitlines()
linesplit
# Out:
# ['Sanu said ', " 'Hiii I am Sanu'"]

# %% [markdown]
# ### Example 2

# %%
showroom_7="Mercedes Manager said \n'Mercedes Welcomes you' "
showroom_7.splitlines()
# Out:
# ['Mercedes Manager said ', "'Mercedes Welcomes you' "]

# %% [markdown]
# ## 1.40 STARTSWITH() - Returns true if the string starts with the specified value

# %% [markdown]
# ### Example 1

# %%
learner_16="Sanu said'Hiii,I am Sanu'"
startwith=learner_16.startswith("Sanu")
startwith
# Out:
# True

# %% [markdown]
# ### Example 2

# %%
showroom_4="Mercedes Manager said'Mercedes Welcomes you' "
showroom_4.startswith("e")
# Out:
# False

# %% [markdown]
# ## 1.41 SWAPCASE() - Swaps cases, lower case becomes upper case and vice versa

# %% [markdown]
# ### Example 1

# %%
learner_5="RaMa_KrisHnA" 
swappingcase=learner_5.swapcase()
swappingcase
# Out:
# 'rAmA_kRIShNa'

# %% [markdown]
# ### Example 2

# %%
car_4="LaNd RoVer"
car_4.swapcase()
# Out:
# 'lAnD rOvER'

# %% [markdown]
# ## 1.42 ISPRINTABLE() - Return True if all characters in the string are printable

# %% [markdown]
# ### Example 1

# %%
learner_16="Sanu said'Hiii,I am Sanu'"
learner_16.isprintable()
# Out:
# True

# %% [markdown]
# ### Example 2

# %%
showroom_7="Mercedes Manager said \n'Mercedes Welcomes you' "
showroom_7.isprintable()
# Out:
# False

# %% [markdown]
# ## 1.43 Atlast these operations doesn't update the original to update in original

# %% [markdown]
# ### Example 1

# %%
learner_1="krish  "
learner_1=learner_1.upper() # Now it will impact the original 
learner_1
# Out:
# 'KRISH  '

# %% [markdown]
# ### Example 2

# %%
car_1="audi   "
cars=car_1.rstrip().title()
cars
# Out:
# 'Audi'
