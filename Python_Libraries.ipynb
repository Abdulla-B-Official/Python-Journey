# %% [markdown]
# ## Libraries
#
# it is a set of functions , modules and classes where it has some pre-written codes to perform some tasks

# %% [markdown]
# ### 1. Pandas Library
#   For Data Analysis

# %%
import pandas as pd
import warnings 
warnings.filterwarnings("ignore")

# %%
insurance_charges=pd.read_csv(filepath_or_buffer=r"C:\Users\Abdul\Downloads\insurance.csv")

# %%
insurance_charges
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ## 2. Numpy - Numerical Operations

# %%
import numpy as np

# %%
np.repeat(a=insurance_charges,repeats=3,axis=0)
# Out:
# array([[19, 'female', 27.9, ..., 'yes', 'southwest', 16884.924],
#        [19, 'female', 27.9, ..., 'yes', 'southwest', 16884.924],
#        [19, 'female', 27.9, ..., 'yes', 'southwest', 16884.924],
#        ...,
#        [61, 'female', 29.07, ..., 'yes', 'northwest', 29141.3603],
#        [61, 'female', 29.07, ..., 'yes', 'northwest', 29141.3603],
#        [61, 'female', 29.07, ..., 'yes', 'northwest', 29141.3603]],
#       shape=(4014, 7), dtype=object)

# %%
vehilce_data_updated=pd.DataFrame(data=np.repeat(a=ev_vehicle,repeats=3,axis=0))

# %%
vehilce_data_updated
# Out:
#                 0          1                  2   3        4     5        6   \
# 0       KM8K33AGXL       King            Seattle  WA  98103.0  2020  HYUNDAI
# 1       KM8K33AGXL       King            Seattle  WA  98103.0  2020  HYUNDAI
# 2       KM8K33AGXL       King            Seattle  WA  98103.0  2020  HYUNDAI
# 3       1C4RJYB61N       King            Bothell  WA  98011.0  2022     JEEP
# 4       1C4RJYB61N       King            Bothell  WA  98011.0  2022     JEEP
# ...            ...        ...                ...  ..      ...   ...      ...
# 451441  5UXTA6C08P  Snohomish  Mountlake Terrace  WA  98043.0  2023      BMW
# 451442  5UXTA6C08P  Snohomish  Mountlake Terrace  WA  98043.0  2023      BMW
# 451443  7SAYGDEF8N     Skagit       Mount Vernon  WA  98273.0  2022    TESLA
# 451444  7SAYGDEF8N     Skagit       Mount Vernon  WA  98273.0  2022    TESLA
# 451445  7SAYGDEF8N     Skagit       Mount Vernon  WA  98273.0  2022    TESLA
#
# ...

# %% [markdown]
# ## 3. Matplotlib ,Seaborn ,Plotly
#
# Data Visualization libraries

# %%
from matplotlib import pyplot as plt

# %%
plt.hist(x = insurance_charges.age)
# Out:
# (array([222., 140., 109., 128., 102., 137., 144., 114., 128., 114.]),
#  array([18. , 22.6, 27.2, 31.8, 36.4, 41. , 45.6, 50.2, 54.8, 59.4, 64. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### 2 Types of Datatypes
# 1.Discrete -Countable ,it wll never have any units you can't measure that
# 2.Continous - it will have units,it is measurable

# %% [markdown]
# ## Seaborn

# %%
import seaborn as sns

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
pip install plotly
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly.express as px
